# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17581, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 17581 (delta 42), reused 12 (delta 10), pack-reused 17508 (from 3)
# Receiving objects: 100% (17581/17581), 16.64 MiB | 12.79 MiB/s, done.
# Resolving deltas: 100% (12036/12036), done.

# %%
# %cd yolov5/
# !pip install -r requirements.txt
# Out:
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# !ls /content/drive/MyDrive/20250916-Yolo/x192
# !cat /content/drive/MyDrive/20250916-Yolo/x192/data.yaml
# Out:
# /content/yolov5
# data.yaml  images  labels
# names:
# - apriltag1
# nc: 1
# train: /content/drive/MyDrive/20250916-Yolo/x192/images/train
# val: /content/drive/MyDrive/20250916-Yolo/x192/images/val

# %%
# !python train.py --img 192 --batch 16 --epochs 50 --data /content/drive/MyDrive/20250916-Yolo/x192/data.yaml --cfg models/yolov5n.yaml --weights yolov5n.pt --name apriltags_yolov5n_x192
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-09-16 11:58:40.378779: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758023920.408679    1056 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !python export.py --weights runs/train/apriltags_yolov5n_x192/weights/best.pt --include saved_model --img 192
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/apriltags_yolov5n_x192/weights/best.pt'], imgsz=[192], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['saved_model']
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from runs/train/apriltags_yolov5n_x192/weights/best.pt with output shape (1, 2268, 6) (3.5 MB)
# 2025-09-03 13:34:01.703812: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python export.py --weights runs/train/apriltags_yolov5n_x192/weights/best.pt --include tflite --img 192
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/apriltags_yolov5n_x192/weights/best.pt'], imgsz=[192], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from runs/train/apriltags_yolov5n_x192/weights/best.pt with output shape (1, 2268, 6) (3.5 MB)
# 2025-09-03 13:34:35.649947: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !tflite_convert \
  --saved_model_dir runs/train/apriltags_yolov5n_x192/weights/best_saved_model \
  --output_file runs/train/apriltags_yolov5n_x192/weights/best.tflite
# Out:
# 2025-09-03 13:35:02.224313: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756906502.242680   19645 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756906502.248219   19645 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756906502.262460   19645 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !zip -r /content/yolov5_runs.zip /content/yolov5/runs/
# Out:
#   adding: content/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/ (stored 0%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/results.png (deflated 10%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/val_batch1_pred.jpg (deflated 17%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/val_batch0_labels.jpg (deflated 17%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/opt.yaml (deflated 50%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/P_curve.png (deflated 21%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/weights/best-fp16.tflite (deflated 8%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/weights/best.pt (deflated 10%)
#   adding: content/yolov5/runs/train/apriltags_yolov5n_x192/weights/best_saved_model/ (stored 0%)
# ...

# %%
from google.colab import files
files.download('/content/yolov5_runs.zip')
